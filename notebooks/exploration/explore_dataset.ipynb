# %%
import pickle
import json
from pathlib import Path
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
data_dir = Path('/gpfs/data/geraslab/ekr6072/projects/study_indication/data')
data_path = data_dir / 'dataset.pkl'

# %%
with open(data_path, 'rb') as f:
  dataset = pickle.load(f)

# %%
label_count = defaultdict(int)
for data in dataset:
  label = data['label']
  label_count[label] += 1

# %%
print(label_count)
# Out:
# defaultdict(<class 'int'>, {'(high-risk) screening': 168, 'extent of disease / pre-operative planning': 61, 'additional workup': 40, 'exclude': 24, '6-month follow-up / surveillance': 48, 'treatment monitoring': 5, 'unknown': 6})

# %%
x = [key for key, value in label_count.items()]
height = [value for key, value in label_count.items()]
plt.barh(x, height)
# Out:
# <BarContainer object of 7 artists>

# %%
lengths = []
for data in dataset:
  length = len(data['text']['longText'].split(' '))
  lengths.append(length)

# %%
fig, ax = plt.subplots()
ax.hist(lengths, bins=10);
ax.set_xlabel('word count per example');
